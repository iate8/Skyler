# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler/blob/main/variables_statements/variables_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#demonstrating variables and statements
money_in_wallet = 15
money_in_bank = 100

total_money = money_in_bank + money_in_wallet

print(money_in_wallet)
print(money_in_bank)
print(total_money)
# Out:
# 15
# 100
# 115

# %%
#import statements
#function definitions
#program logic
#assign valuables to variables: Name, goal, birth_year, current_year
name = "john smith"
goal = "rule the world"
birth_year = 1971
current_year = 2026
#calculate age
age = current_year - birth_year
#print top border
print("=" * 25)
#print bios
print("my name is", name, "and I am", str(age), "years old.")
#print bottom boarder
# Out:
# ...
# my name is john smith and I am 55 years old
