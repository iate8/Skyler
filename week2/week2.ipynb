# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler/blob/main/week2/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIC
# 1. Print the total minutes in a movie (2 * 60 + 45).
print("Total minutes in a movie: "+str(2 * 60 + 45))

# 2. Print the years since 1947 (2026 - 1947).
print("The year since 1947: "+str(2026 - 1947))

# 3. Print the total cost of 7 books (7 * 35).
print("Total cost of 7 books: "+ str(7 * 35))
# Out:
# Total minutes in a movie: 165
# The year since 1947: 79
# Total cost of 7 books: 245
