# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler/blob/main/week5/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pricing Rules

Standard_Price = 12.00
Child_Price = 8.00
Senior_Price = 8.00
Matinee_Discount = 2.00

# %%
# IMPORT STATEMENTS (None)

# FUNCTION DEFINITIONS

# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):

# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
if age <= 12 or age >= 65:
price = 8.00
else:
price = 12.00

# 3. Logic: If hour < 17, subtract 2 from the price.

# 4. Return the final price.

# 4. Print the final price.
print(price)


# PROGRAM LOGIC
# 1. input() for age (int)

# 2. input() for movie hour (int)

# 3. Call calculate_ticket()
calculate_ticket(19,19)
