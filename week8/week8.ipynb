# %% [markdown]
# <a href="https://colab.research.google.com/github/iate8/Skyler/blob/main/week8/week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# is_palindrome

# PROGRAM LOGIC
